# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
import seaborn as sns; sns.set_style('darkgrid')

# %%
def corr(n, samplesize=100):
    
    rs = np.array([])
    
    for i in range(n):
        X1 = np.random.sample(samplesize)
        X2 = np.random.sample(samplesize)
        r = sts.pearsonr(X1, X2)
        rs = np.append(rs, r)
    
    return rs

# %%
for i in [10,100,1000,10000]:
    a = sns.distplot(corr(1000, samplesize=i), hist=False,
                     axlabel='Pearsons R', label=str(i))
